# %%
import pandas as pd

# %%
df1=pd.read_csv(r"C:\Users\SRINATH\Desktop\data science\machine learing\ml project\data\raw\aa_dataset-tickets-multi-lang-5-2-50-version.csv")

# %%
df1.head(1)
# Out:
#                            subject  \
# 0  Wesentlicher Sicherheitsvorfall
#
#                                                 body  \
# 0  Sehr geehrtes Support-Team,\n\nich möchte eine...
#
#                                               answer      type  \
# 0  Vielen Dank für die Meldung des kritischen Sic...  Incident
#
#                queue priority language  version     tag_1   tag_2       tag_3  \
# 0  Technical Support     high       de       51  Security  Outage  Disruption
#
#          tag_4 tag_5 tag_6 tag_7 tag_8
# 0  Data Breach   NaN   NaN   NaN   NaN

# %%
df2=pd.read_csv(r"C:\Users\SRINATH\Desktop\data science\machine learing\ml project\data\raw\twcs.csv")

# %%
df2.head(1)
# Out:
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
#
#    in_response_to_tweet_id
# 0                      3.0

# %%
df3=pd.read_csv(r"C:\Users\SRINATH\Desktop\data science\machine learing\ml project\data\raw\ultra_synthetic_200k_v2.csv")

# %%
df3.head(1)
# Out:
#         subject                                               body  \
# 0  System crash  Hello team, I'm reporting a incident involving...
#
#                                               answer      type  \
# 0  Thank you for contacting Technical Support. We...  Incident
#
#                queue priority language            tag_1  \
# 0  Technical Support      low       en  complete outage
#
#                      action  ttr_hours  \
# 0  restart affected service       2.68
#
#                                            full_text  \
# 0  System crash Hello team, I'm reporting a incid...
#
#                                           clean_text
# 0  system crash hello team, i'm reporting a incid...
